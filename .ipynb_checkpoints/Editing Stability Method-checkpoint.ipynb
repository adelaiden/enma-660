# %%
from pymatgen import MPRester, Element, Composition
from pymatgen.phasediagram.analyzer import PhaseDiagram
from pymatgen.phasediagram.entries import PDEntry
from pymatgen.analysis.reaction_calculator import ComputedReaction
import matplotlib.pyplot as plt
import math
import scipy.constants as sc
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymatgen/phasediagram/__init__.py:17: UserWarning: pymatgen.phasediagram and submodules has been moved to pymatgen.analysis.phase_diagram This stub will be removed in pmg 2018.01.01.
#   warnings.warn("pymatgen.phasediagram and submodules has been moved to "
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymatgen/phasediagram/analyzer.py:3: UserWarning: pymatgen.phasediagram and submodules has been moved to pymatgen.analysis.phase_diagram This stub will be removed in pmg 2018.01.01.
#   warnings.warn("pymatgen.phasediagram and submodules has been moved to "
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymatgen/phasediagram/entries.py:3: UserWarning: pymatgen.phasediagram and submodules has been moved to pymatgen.analysis.phase_diagram This stub will be removed in pmg 2018.01.01.
#   warnings.warn("pymatgen.phasediagram and submodules has been moved to "

# %%
def high_temp_correction(e, temp, expt=False):
    '''Performs high-temp correction for the supplied entry, given the new temperature.'''
    entropies = dict(O2=(205.152/2), SO2=(248.223/3), SO3=(256.77/4), P2O5=(403.96/14), CO2=(213.795/3)) 
                    #gas phase entropy values
    pressures = dict(O2=0.2, SO2=10**-6, SO3=10**-6, P2O5=10**-8, CO2=0.04) #in atm
    s_e = entropies[e.name]/sc.N_A
    h_corr = 3.5*sc.k*(temp - 298)
    p_new = pressures[e.name]
    p_std = 1
    comp, factor = e.composition.get_reduced_composition_and_factor()
    na = e.composition.num_atoms/factor
    g500 = dict(O2=(h_corr- temp*s_e)*sc.N_A, SO2=-300.871, SO3=-352.668, CO2=-394.939, P2O5=-2507.262)
    g800 = dict(O2=(h_corr- temp*s_e)*sc.N_A, SO2=-298.370, SO3=-321.912, CO2=-395.586, P2O5=-2264.308)
    new_miu = ((h_corr - temp*s_e + sc.k*temp*math.log(p_new/p_std))/(na))/sc.e
    if expt: #only for 500 K and 800 K
        if temp == 500:
            new_miu = ((g500[e.name]/sc.N_A + sc.k*temp*math.log(p_new/p_std))/na)/sc.e
        if temp == 800:
            new_miu = ((g800[e.name]/sc.N_A + sc.k*temp*math.log(p_new/p_std))/na)/sc.e
    e.correction += new_miu*e.composition.num_atoms
    return new_miu

# %%
def get_chempots_phases_enthalpies(chsys, form, elem, temp=298, binary=None):
    chempots = [] #critical chemical potentials at every transition point
    evolutions = [] 
    phases = []
    enthalpies = []
    reactions = []
    yvec = []
    
    exclusion_list = ['LiS4','S8O']
    gas_phase_list = ['O2','CO2','SO2','SO3'] #remove O2 if you want to compare at 0
    gas_corr_dict = dict(O2=0, CO2=0, SO2=0, SO3=0) 
    
    if binary != None:
        entries, formula, compound = get_binary_entries(chsys, form, binary, elem, 0.5)
        
    else:
        formula = form
        with MPRester() as m:
            entries = m.get_entries_in_chemsys(chsys)
            mpentry = m.get_entries(formula) #gets all MP-entries associated with given composition

        pd = PhaseDiagram(entries) #initialize pd with all metastable entries

        if len(mpentry) == 0: #composition is metastable, so force it to lie on the convex hull
            compound = PDEntry(Composition(formula), 0)
            e0 = pd.get_e_above_hull(compound)
            compound = PDEntry(Composition(formula), -(e0*Composition(formula).num_atoms + 1e-8))
            entries.append(compound)
        else: #otherwise return the most stable entry in the list of MP-entries. This entry can be metastable.
                #in the future, may want to include a shift of "e-above-hull" to set this compound on the x-axis
            mpentry = sorted(mpentry, key=lambda e: e.energy_per_atom)
            compound = mpentry[0]
            entries.append(compound)
    
    #for high temp case, change e.correction of applicable entries
    if temp != 298:
        for e in entries:
            if e.name in gas_phase_list:
                corr = high_temp_correction(e, temp, expt=True)
                if gas_corr_dict[e.name] == 0:
                    gas_corr_dict[e.name] = corr
        print gas_corr_dict
    
    entries = [e for e in entries if e.name not in exclusion_list] 
    
    pd = PhaseDiagram(entries) #final pd with entries artificially shifted to hull
    evolution_profile = pd.get_element_profile(Element(elem), Composition(formula))
    ref = evolution_profile[0]['element_reference'].energy_per_atom
    
    reac = [compound, evolution_profile[0]['element_reference']]
    
    for stage in evolution_profile: #get chemical potentials and phases
        chempots.append(stage['chempot'] - ref)
        evolutions.append(stage['evolution'])
        namelist = []
        for entry in stage['entries']:
            namelist.append(entry.name)
        phases.append(namelist)
    
    yshift = 0  #initialize y-shift
    window = False #assume the compound has no stability window at first
    
    if binary == None:
        foo, factor = compound.composition.get_reduced_composition_and_factor()
        natoms = compound.composition.num_atoms/factor
    else:
        natoms = 0.5

    for stage in evolution_profile:
        rxn = ComputedReaction(reac, stage['entries']) #calculate reaction enthalpy
        rxn.normalize_to(Composition(formula))
        enthalpies.append(rxn.calculated_reaction_energy) #normalized per F.U. of material
        reactions.append(str(rxn))
        if abs(stage['evolution']) < 0.0001: #compound has a stability window
            window = True
            yshift = stage['evolution']*stage['chempot'] + rxn.calculated_reaction_energy

    for i in range(len(chempots)): #manipulate and shift data for graphs
        ynew = ((evolutions[i]*(-chempots[i]) + enthalpies[i]) - yshift)/natoms #normalize to eV/atom
        yvec.append(ynew)
        enthalpies[i] = (enthalpies[i])/natoms #shift to normalize to eV/atom
    chempots_shifted = []
    for c in chempots:
        chempots_shifted.append(c + gas_corr_dict['O2']) 
    
    return [chempots, phases, yvec, enthalpies, reactions, chempots_shifted]

# %%
def get_binary_entries(chsys, formula1, formula2, elem, r):
    '''Provides the forumula and entries for a pseudo-binary with ratio r, given the compositions of the two
    constituent compounds.'''
    with MPRester() as m:
        entries = m.get_entries_in_chemsys(chsys)
        mpentries1 = m.get_entries(formula1)
        mpentries2 = m.get_entries(formula2)
        
    pd = PhaseDiagram(entries)
    
    #for each material, check if it exists in the database and return the most stable entry
    if len(mpentries1) != 0: #material exists in database
        mpentries1 = sorted(mpentries1, key=lambda e: e.energy_per_atom)
        m1 = mpentries1[0]
    else: #not in database, make one
        m1 = PDEntry(Composition(formula1), 0)
        e0 = pd.get_e_above_hull(m1)
        m1 = PDEntry(Composition(formula1), -(e0*Composition(formula1).num_atoms))
    entries.append(m1)
    
    if len(mpentries2) != 0:
        mpentries2 = sorted(mpentries2, key=lambda e: e.energy_per_atom)
        m2 = mpentries2[0]
    else:
        m2 = PDEntry(Composition(formula2), 0)
        e0 = pd.get_e_above_hull(m2)
        m2 = PDEntry(Composition(formula2), -(e0*Composition(formula2).num_atoms))
    entries.append(m2)
    
    m1C = Composition(m1.name)
    m2C = Composition(m2.name)
    
    E0 = m1.energy_per_atom * r + m2.energy_per_atom * (1 - r)
    comp = (1/m1C.num_atoms) * r * m1C + (1/m2C.num_atoms) * (1 - r) * m2C
    
    comp_entry = PDEntry(comp, (E0 + 1e-8))
    entries.append(comp_entry)
    
    return entries, comp, comp_entry

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.font_manager
import matplotlib.patches as patches

# mpl.rcdefaults()

f_size = 18
mpl.rcParams['xtick.labelsize']=f_size
mpl.rcParams['ytick.labelsize']=f_size
mpl.rcParams['axes.labelweight']='light'
mpl.rcParams['axes.labelsize']=f_size
mpl.rcParams['font.size']=f_size
mpl.rcParams['font.family']='sans-serif'
mpl.rcParams['font.sans-serif']='Arial'
mpl.rcParams['font.style']='normal'
mpl.rcParams['font.weight']='light'
mpl.rcParams['mathtext.fontset'] = 'custom'
mpl.rcParams['mathtext.rm'] = 'Arial'
mpl.rcParams["figure.figsize"] = (8,5)

import pandas as pnds
colo1='#107ab0'
colo2='#ff9408'
colo3='#4da409'

# %% [markdown]
# ## Delithiated LiCoO2 comparisons

# %%
L_CO = get_chempots_phases_enthalpies(['Li','Co','O'],'Li0.5CoO2','O')
LCO = get_chempots_phases_enthalpies(['Li','Co','O'],'LiCoO2','O')

# %%
pnds.options.display.float_format = '{:.3f}'.format

table1 = pnds.DataFrame({r'$\mu_O$* (eV)':LCO[0],
                      'Phase Equilibria':LCO[1],
                     r'$\Delta H_{rxn}$ at $\mu_O$ = 0.0':LCO[3],
                    r'$\Delta H_{rxn}$ at $\mu_O$*':LCO[2],
                        'Reaction':LCO[4]})
table2 = pnds.DataFrame({r'$\mu_O$* (eV)':L_CO[0],
                      'Phase Equilibria':L_CO[1],
                     r'$\Delta H_{rxn}$ at $\mu_O$ = 0.0':L_CO[3],
                    r'$\Delta H_{rxn}$ at $\mu_O$*':L_CO[2],
                        'Reaction':L_CO[4]})
display(table1)
display(table2)
# Out:
#    $\Delta H_{rxn}$ at $\mu_O$ = 0.0  $\Delta H_{rxn}$ at $\mu_O$*  \
# 0                             -0.021                        -0.021
# 1                             -0.000                         0.000
# 2                              0.331                         0.000
# 3                              0.885                        -0.002
# 4                              1.006                        -0.083
# 5                              1.782                        -1.324
#
#    $\mu_O$* (eV)        Phase Equilibria  \
# 0          0.000  [Li7Co5O12, Li(CoO2)2]
# 1         -0.378                [LiCoO2]
# 2         -2.644          [CoO, Li6CoO4]
# 3         -2.660           [Co, Li6CoO4]
# 4         -2.903              [Li2O, Co]
# 5         -6.213                [Co, Li]
#
#                                                     Reaction
# 0  0.1111 O2 + LiCoO2 -> 0.2222 Li(CoO2)2 + 0.1111 Li7Co5O12
# 1                                           LiCoO2 -> LiCoO2
# 2            LiCoO2 -> 0.25 O2 + 0.8333 CoO + 0.1667 Li6CoO4
# 3           LiCoO2 -> 0.6667 O2 + 0.8333 Co + 0.1667 Li6CoO4
# 4                          LiCoO2 -> 0.75 O2 + Co + 0.5 Li2O
# 5                                     LiCoO2 -> O2 + Li + Co
#    $\Delta H_{rxn}$ at $\mu_O$ = 0.0  $\Delta H_{rxn}$ at $\mu_O$*  \
# 0                             -0.000                         0.000
# 1                              0.070                         0.000
# 2                              0.162                        -0.115
# 3                              0.351                        -0.216
# 4                              1.047                        -0.219
# 5                              1.117                        -0.335
# 6                              1.560                        -1.990
#
#    $\mu_O$* (eV) Phase Equilibria  \
# 0          0.000     [Li0.5Co1O2]
# 1         -0.730  [Co3O4, LiCoO2]
# 2         -1.940    [LiCoO2, CoO]
# 3         -2.644   [Li6CoO4, CoO]
# 4         -2.660    [Co, Li6CoO4]
# 5         -2.903       [Li2O, Co]
# 6         -6.213         [Co, Li]
#
#                                                 Reaction
# 0                               Li0.5Co1O2 -> Li0.5Co1O2
# 1    Li0.5Co1O2 -> 0.1667 O2 + 0.1667 Co3O4 + 0.5 LiCoO2
# 2           Li0.5Co1O2 -> 0.25 O2 + 0.5 CoO + 0.5 LiCoO2
# 3  Li0.5Co1O2 -> 0.375 O2 + 0.9167 CoO + 0.08333 Li6CoO4
# 4  Li0.5Co1O2 -> 0.8333 O2 + 0.9167 Co + 0.08333 Li6CoO4
# 5                Li0.5Co1O2 -> 0.875 O2 + Co + 0.25 Li2O
# 6                         Li0.5Co1O2 -> O2 + 0.5 Li + Co

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')


p1 = plt.plot((LCO[0]), LCO[2], 'o-', label= r'LiCoO$_2$')
p2 = plt.plot((L_CO[0]), L_CO[2], 'o-', label= r'Li$_{0.5}$CoO$_2$')

legend = ax.legend(loc='lower left')

ax.invert_xaxis()
plt.show()

# %%
L_CO_500 = get_chempots_phases_enthalpies(['Li','Co','O'],'Li0.5CoO2','O', temp=500)
LCO_500 = get_chempots_phases_enthalpies(['Li','Co','O'],'LiCoO2','O', temp=500)
L_CO_800 = get_chempots_phases_enthalpies(['Li','Co','O'],'Li0.5CoO2','O', temp=800)
LCO_800 = get_chempots_phases_enthalpies(['Li','Co','O'],'LiCoO2','O', temp=800)
# Out:
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LCO[0], LCO[2], 'o-', c=colo1, label= r'LiCoO$_2$, 298 K')
p2 = plt.plot(LCO_500[5], LCO_500[2], 'o-', c=colo2, label= r'LiCoO$_2$, 500 K')
p3 = plt.plot(LCO_800[5], LCO_800[2], 'o-', c=colo3, label= r'LiCoO$_2$, 800 K')

p4 = plt.plot(L_CO[0], L_CO[2], 'o--', c=colo1, label= r'Li$_{0.5}$CoO$_2$, 298 K')
p5 = plt.plot(L_CO_500[5], L_CO_500[2], 'o--', c=colo2, label= r'Li$_{0.5}$CoO$_2$, 500 K')
p6 = plt.plot(L_CO_800[5], L_CO_800[2], 'o--', c=colo3, label= r'Li$_{0.5}$CoO$_2$, 800 K')

legend = ax.legend(loc='lower left')

ax.invert_xaxis()
plt.show()

# %% [markdown]
# ## LATP

# %%
LATP_LCO = get_chempots_phases_enthalpies(['Li','Al','Ti','P','Co','O'],'Li1.3Al0.3Ti1.7P3O12','O', binary='LiCoO2')
LATP_L_CO = get_chempots_phases_enthalpies(['Li','Al','Ti','P','Co','O'],'Li1.3Al0.3Ti1.7P3O12','O', binary='Li0.5CoO2')

# %%
s = 'Li0.1069477Ti0.04644809Al0.00819672Co0.14285714P0.08196721O0.61358314'
shortname = []
for r in LATP_L_CO[4]:
    new = r.replace(s, 'LATP-L(0.5)CO')
    shortname.append(new)
    
table = pnds.DataFrame({r'$\mu_O$* (eV)':LATP_L_CO[5],
                      'Phase Equilibria':LATP_L_CO[1],
                     r'$\Delta H_{rxn}$ at $\mu_O$ = 0.0':LATP_L_CO[3],
                    r'$\Delta H_{rxn}$ at $\mu_O$*':LATP_L_CO[2]})
reactions = pnds.DataFrame({'Reaction':shortname})
pnds.set_option('max_colwidth', 400)

display(table)
display(reactions)
# Out:
#     $\Delta H_{rxn}$ at $\mu_O$ = 0.0  $\Delta H_{rxn}$ at $\mu_O$*  \
# 0                              -0.004                        -0.004
# 1                              -0.000                        -0.000
# 2                               0.027                        -0.000
# 3                               0.030                        -0.031
# 4                               0.050                        -0.052
# 5                               0.064                        -0.141
# 6                               0.086                        -0.183
# 7                               0.116                        -0.268
# 8                               0.130                        -0.270
# 9                               0.146                        -0.278
# 10                              0.268                        -0.424
# 11                              0.391                        -0.424
# 12                              0.522                        -0.472
# 13                              0.617                        -0.498
# 14                              0.904                        -0.575
# 15                              0.972                        -0.600
# 16                              1.089                        -0.669
# 17                              1.602                        -0.686
# 18                              1.753                        -0.782
# 19                              1.987                        -1.021
# 20                              2.217                        -1.022
# 21                              2.232                        -1.139
# 22                              2.237                        -1.222
# 23                              2.412                        -1.291
# 24                              2.503                        -1.357
# 25                              2.819                        -1.850
# 26                              2.832                        -1.867
# 27                              2.843                        -1.929
# 28                              2.864                        -2.079
# 29                              2.908                        -2.454
# 30                              2.980                        -2.594
# 31                              3.095                        -2.611
# 32                              3.260                        -2.666
# 33                              3.430                        -2.729
# 34                              4.105                        -2.761
#
#     $\mu_O$* (eV)                                Phase Equilibria
# 0           0.000     [LiTi2(PO4)3, AlPO4, LiTiPO5, Li3PO4, CoO2]
# 1          -0.051         [LiTi2(PO4)3, Li(CoO2)2, Li3PO4, AlPO4]
# 2          -0.225    [LiTi2(PO4)3, AlPO4, LiTiPO5, Li3PO4, Co3O4]
# 3          -0.489        [AlPO4, Co3O4, LiTiPO5, Li3PO4, LiCoPO4]
# 4          -0.649           [TiO2, AlPO4, LiCoPO4, Li3PO4, Co3O4]
# 5          -1.219       [TiO2, Co3O4, Al(CoO2)2, Li3PO4, LiCoPO4]
# 6          -1.470    [Ti2CoO5, Co3O4, Al(CoO2)2, Li3PO4, LiCoPO4]
# 7          -1.932     [LiCoPO4, Co3O4, Al(CoO2)2, Li3PO4, TiCoO3]
# 8          -1.940       [Li3PO4, LiCoPO4, Al(CoO2)2, CoO, TiCoO3]
# 9          -1.978         [Al2CoO4, LiCoPO4, TiCoO3, Li3PO4, CoO]
# 10         -2.660          [Co, Al2CoO4, TiCoO3, Li3PO4, LiCoPO4]
# 11         -2.663         [Co, Ti2CoO5, LiCoPO4, Li3PO4, Al2CoO4]
# 12         -2.817            [Co, Al2CoO4, LiCoPO4, Li3PO4, TiO2]
# 13         -2.891              [Co, TiO2, LiCoPO4, Li3PO4, AlPO4]
# 14         -3.090           [Co, AlPO4, LiTiPO5, Li3PO4, LiCoPO4]
# 15         -3.144       [Co, LiTi2(PO4)3, LiTiPO5, Li3PO4, AlPO4]
# 16         -3.282              [Co, Co2P, LiTiPO5, Li3PO4, AlPO4]
# 17         -3.314                 [Co, Co2P, AlPO4, Li3PO4, TiO2]
# 18         -3.452               [Co, Co2P, LiAl5O8, Li3PO4, TiO2]
# 19         -3.777          [Co, Co2P, Li4Ti5O12, Li3PO4, LiAl5O8]
# 20         -3.779     [Co2P, Li2TiO3, Li4Ti5O12, Li3PO4, LiAl5O8]
# 21         -3.915    [Co2P, Li2TiO3, LiAl5O8, Li3PO4, Li7Ti11O24]
# 22         -4.012     [Co2P, Li2TiO3, Li7Ti11O24, Li3PO4, LiAlO2]
# 23         -4.092      [Co2P, Li2TiO3, LiAlO2, Li3PO4, Ti2Co12P7]
# 24         -4.165  [Co2P, Li2TiO3, Ti2Co12P7, LiAlO2, Li(Co3P2)2]
# 25         -4.696     [Co2P, Li2TiO3, Ti2Co12P7, Li4TiO4, LiAlO2]
# 26         -4.714          [Co, Co2P, Ti2Co12P7, Li4TiO4, LiAlO2]
# 27         -4.776    [Co, Li(Co3P2)2, Ti2Co12P7, Li4TiO4, LiAlO2]
# 28         -4.926       [Co, Li5AlO4, Ti2Co12P7, Li4TiO4, LiAlO2]
# 29         -5.299  [Li5AlO4, Ti2Co12P7, Li4TiO4, TiAlCo2, LiAlO2]
# 30         -5.438   [Ti4P3, Ti2Co12P7, Li4TiO4, TiAlCo2, Li5AlO4]
# 31         -5.455    [Li5AlO4, Ti2Co12P7, Li4TiO4, TiAlCo2, Li3P]
# 32         -5.507       [Ti2Co12P7, TiAlCo2, Li4TiO4, Li2O, Li3P]
# 33         -5.566      [Ti2Co12P7, Li3P, Li4TiO4, TiAlCo2, TiCo3]
# 34         -5.595        [Ti5P3, Ti2Co12P7, TiCo3, TiAlCo2, Li3P]
#                                                                                                                     Reaction
# 0       LATP-L(0.5)CO + 0.01786 O2 -> 0.005367 LiTi2(PO4)3 + 0.03571 LiTiPO5 + 0.02196 Li3PO4 + 0.1429 CoO2 + 0.008197 AlPO4
# 1                                LATP-L(0.5)CO -> 0.02322 LiTi2(PO4)3 + 0.004098 Li3PO4 + 0.008197 AlPO4 + 0.07143 Li(CoO2)2
# 2     LATP-L(0.5)CO -> 0.02976 O2 + 0.005367 LiTi2(PO4)3 + 0.03571 LiTiPO5 + 0.02196 Li3PO4 + 0.04762 Co3O4 + 0.008197 AlPO4
# 3          LATP-L(0.5)CO -> 0.03155 O2 + 0.04645 LiTiPO5 + 0.01659 Li3PO4 + 0.04404 Co3O4 + 0.008197 AlPO4 + 0.01073 LiCoPO4
# 4             LATP-L(0.5)CO -> 0.03929 O2 + 0.01659 Li3PO4 + 0.02856 Co3O4 + 0.008197 AlPO4 + 0.05718 LiCoPO4 + 0.04645 TiO2
# 5           LATP-L(0.5)CO -> 0.04202 O2 + 0.008197 Al(CoO2)2 + 0.01249 Li3PO4 + 0.019 Co3O4 + 0.06948 LiCoPO4 + 0.04645 TiO2
# 6       LATP-L(0.5)CO -> 0.0459 O2 + 0.008197 Al(CoO2)2 + 0.02322 Ti2CoO5 + 0.01249 Li3PO4 + 0.01125 Co3O4 + 0.06948 LiCoPO4
# 7      LATP-L(0.5)CO -> 0.04977 O2 + 0.008197 Al(CoO2)2 + 0.04645 TiCoO3 + 0.01249 Li3PO4 + 0.003513 Co3O4 + 0.06948 LiCoPO4
# 8         LATP-L(0.5)CO -> 0.05152 O2 + 0.008197 Al(CoO2)2 + 0.04645 TiCoO3 + 0.01249 Li3PO4 + 0.01054 CoO + 0.06948 LiCoPO4
# 9           LATP-L(0.5)CO -> 0.05357 O2 + 0.004098 Al2CoO4 + 0.04645 TiCoO3 + 0.01249 Li3PO4 + 0.02283 CoO + 0.06948 LiCoPO4
# 10           LATP-L(0.5)CO -> 0.06499 O2 + 0.004098 Al2CoO4 + 0.04645 TiCoO3 + 0.01249 Li3PO4 + 0.02283 Co + 0.06948 LiCoPO4
# 11           LATP-L(0.5)CO -> 0.0766 O2 + 0.004098 Al2CoO4 + 0.02322 Ti2CoO5 + 0.01249 Li3PO4 + 0.04606 Co + 0.06948 LiCoPO4
# 12             LATP-L(0.5)CO -> 0.08821 O2 + 0.004098 Al2CoO4 + 0.01249 Li3PO4 + 0.06928 Co + 0.06948 LiCoPO4 + 0.04645 TiO2
# 13               LATP-L(0.5)CO -> 0.09641 O2 + 0.01659 Li3PO4 + 0.08568 Co + 0.008197 AlPO4 + 0.05718 LiCoPO4 + 0.04645 TiO2
# 14              LATP-L(0.5)CO -> 0.1196 O2 + 0.04645 LiTiPO5 + 0.01659 Li3PO4 + 0.1321 Co + 0.008197 AlPO4 + 0.01073 LiCoPO4
# 15          LATP-L(0.5)CO -> 0.125 O2 + 0.005367 LiTi2(PO4)3 + 0.03571 LiTiPO5 + 0.02196 Li3PO4 + 0.1429 Co + 0.008197 AlPO4
# 16                LATP-L(0.5)CO -> 0.1339 O2 + 0.04645 LiTiPO5 + 0.007156 Co2P + 0.1285 Co + 0.008197 AlPO4 + 0.02017 Li3PO4
# 17                   LATP-L(0.5)CO -> 0.1727 O2 + 0.03812 Co2P + 0.06661 Co + 0.008197 AlPO4 + 0.03565 Li3PO4 + 0.04645 TiO2
# 18                  LATP-L(0.5)CO -> 0.1836 O2 + 0.001639 LiAl5O8 + 0.04686 Co2P + 0.04913 Co + 0.0351 Li3PO4 + 0.04645 TiO2
# 19            LATP-L(0.5)CO -> 0.1991 O2 + 0.001639 LiAl5O8 + 0.00929 Li4Ti5O12 + 0.05925 Co2P + 0.02436 Co + 0.02272 Li3PO4
# 20      LATP-L(0.5)CO -> 0.2143 O2 + 0.001639 LiAl5O8 + 0.03044 Li2TiO3 + 0.07143 Co2P + 0.01054 Li3PO4 + 0.003201 Li4Ti5O12
# 21      LATP-L(0.5)CO -> 0.2152 O2 + 0.001639 LiAl5O8 + 0.03237 Li2TiO3 + 0.07143 Co2P + 0.01054 Li3PO4 + 0.00128 Li7Ti11O24
# 22      LATP-L(0.5)CO -> 0.2156 O2 + 0.008197 LiAlO2 + 0.02756 Li2TiO3 + 0.07143 Co2P + 0.01054 Li3PO4 + 0.001717 Li7Ti11O24
# 23       LATP-L(0.5)CO -> 0.2262 O2 + 0.008197 LiAlO2 + 0.03909 Li2TiO3 + 0.04935 Co2P + 0.006858 Li3PO4 + 0.00368 Ti2Co12P7
# 24   LATP-L(0.5)CO -> 0.2317 O2 + 0.0009368 Ti2Co12P7 + 0.04457 Li2TiO3 + 0.037 Co2P + 0.009602 Li(Co3P2)2 + 0.008197 LiAlO2
# 25       LATP-L(0.5)CO -> 0.2485 O2 + 0.01054 Ti2Co12P7 + 0.001366 Li2TiO3 + 0.008197 Co2P + 0.008197 LiAlO2 + 0.024 Li4TiO4
# 26         LATP-L(0.5)CO -> 0.2492 O2 + 0.01088 Ti2Co12P7 + 0.02469 Li4TiO4 + 0.005806 Co2P + 0.0006831 Co + 0.008197 LiAlO2
# 27    LATP-L(0.5)CO -> 0.2498 O2 + 0.01103 Ti2Co12P7 + 0.02439 Li4TiO4 + 0.003363 Co + 0.001191 Li(Co3P2)2 + 0.008197 LiAlO2
# 28       LATP-L(0.5)CO -> 0.2509 O2 + 0.001659 Li5AlO4 + 0.01171 Ti2Co12P7 + 0.002342 Co + 0.006538 LiAlO2 + 0.02303 Li4TiO4
# 29  LATP-L(0.5)CO -> 0.2529 O2 + 0.003123 Li5AlO4 + 0.01171 Ti2Co12P7 + 0.003903 LiAlO2 + 0.001171 TiAlCo2 + 0.02186 Li4TiO4
# 30  LATP-L(0.5)CO -> 0.2563 O2 + 0.01152 Ti2Co12P7 + 0.01936 Li4TiO4 + 0.0004372 Ti4P3 + 0.002295 TiAlCo2 + 0.005902 Li5AlO4
# 31    LATP-L(0.5)CO -> 0.2615 O2 + 0.003279 Li5AlO4 + 0.01109 Ti2Co12P7 + 0.004372 Li3P + 0.004918 TiAlCo2 + 0.01936 Li4TiO4
# 32        LATP-L(0.5)CO -> 0.269 O2 + 0.01054 Ti2Co12P7 + 0.01717 Li4TiO4 + 0.008197 Li3P + 0.006831 Li2O + 0.008197 TiAlCo2
# 33      LATP-L(0.5)CO -> 0.2766 O2 + 0.009488 Ti2Co12P7 + 0.01507 Li4TiO4 + 0.01555 Li3P + 0.008197 TiAlCo2 + 0.004203 TiCo3
# 34        LATP-L(0.5)CO -> 0.3068 O2 + 0.005934 Ti2Co12P7 + 0.01842 TiCo3 + 0.03565 Li3P + 0.001593 Ti5P3 + 0.008197 TiAlCo2

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LATP_LCO[0], LATP_LCO[2], 'o-', label= r'LATP-LiCoO$_2$')
p2 = plt.plot(LATP_L_CO[0], LATP_L_CO[2], 'o-', label= r'LATP-Li$_{0.5}$CoO$_2$')
legend = ax.legend(loc='lower center')

ax.invert_xaxis()
plt.show()

# %%
LATP_LCO_500 = get_chempots_phases_enthalpies(['Li','Al','Ti','P','Co','O'],'Li13Al3Ti17P30O120','O', temp=500, binary='LiCoO2')
LATP_L_CO_500 = get_chempots_phases_enthalpies(['Li','Al','Ti','P','Co','O'],'Li13Al3Ti17P30O120','O', temp=500, binary='Li0.5CoO2')
LATP_LCO_800 = get_chempots_phases_enthalpies(['Li','Al','Ti','P','Co','O'],'Li13Al3Ti17P30O120','O', temp=800, binary='LiCoO2')
LATP_L_CO_800 = get_chempots_phases_enthalpies(['Li','Al','Ti','P','Co','O'],'Li13Al3Ti17P30O120','O', temp=800, binary='Li0.5CoO2')
# Out:
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LATP_LCO[0], LATP_LCO[2], 'o-', c='#107ab0', label= r'latp-lco, 298 K')
p2 = plt.plot(LATP_LCO_500[5], LATP_LCO_500[2], 'o-', c='#ff9408', label= r'latp-lco, 500 K')
p3 = plt.plot(LATP_LCO_800[5], LATP_LCO_800[2], 'o-', c='#4da409', label= r'latp-lco, 800 K')

# p4 = plt.plot(LATP_L_CO[0], LATP_L_CO[2], 'o--', c='#107ab0', label= r'latp-l$_{0.5}$co, 300 K')
# p5 = plt.plot(LATP_L_CO_500[5], LATP_L_CO_500[2], 'o--', c='#ff9408', label= r'latp-l$_{0.5}$co, 500 K')
# p6 = plt.plot(LATP_L_CO_800[5], LATP_L_CO_800[2], 'o--', c='#4da409', label= r'latp-l$_{0.5}$co, 800 K')
ax.legend(loc='lower left')
ax.invert_xaxis()
plt.show()

# %% [markdown]
# ## LPS

# %%
LPS = get_chempots_phases_enthalpies(['Li','P','S','O'],'Li3PS4','O')

# %%
LPS_LCO = get_chempots_phases_enthalpies(['Li','P','S','Co','O'],'Li3PS4','O', binary='LiCoO2')
LPS_L_CO = get_chempots_phases_enthalpies(['Li','P','S','Co','O'],'Li3PS4','O', binary='Li0.5CoO2')

# %%
s = 'Li0.25892857Co0.14285714P0.0625S0.25O0.28571429'
shortname = []
for r in LPS_L_CO[4]:
    new = r.replace(s, 'LPS-L(0.5)CO')
    shortname.append(new)
    
table = pnds.DataFrame({r'$\mu_O$* (eV)':LPS_L_CO[5],
                      'Phase Equilibria':LPS_L_CO[1],
                     r'$\Delta H_{rxn}$ at $\mu_O$ = 0.0':LPS_L_CO[3],
                    r'$\Delta H_{rxn}$ at $\mu_O$*':LPS_L_CO[2],
                        'Reaction':shortname})
pnds.set_option('max_colwidth', 400)

display(table)
# Out:
#     $\Delta H_{rxn}$ at $\mu_O$ = 0.0  $\Delta H_{rxn}$ at $\mu_O$*  \
# 0                              -5.594                        -5.594
# 1                              -5.586                        -5.214
# 2                              -5.585                        -5.167
# 3                              -5.584                        -5.144
# 4                              -5.576                        -4.651
# 5                              -5.534                        -1.396
# 6                              -5.281                        -1.351
# 7                              -3.553                        -1.289
# 8                              -3.173                        -1.260
# 9                              -2.999                        -1.258
# 10                             -2.831                        -1.208
# 11                             -2.325                        -1.200
# 12                             -2.096                        -1.181
# 13                             -1.724                        -1.166
# 14                             -0.848                        -1.067
# 15                             -0.671                        -1.113
# 16                             -0.179                        -1.132
# 17                              1.129                        -1.167
#
#     $\mu_O$* (eV)                       Phase Equilibria  \
# 0           0.000        [Li2SO4, CoPO4, CoSO4, Li2S2O7]
# 1          -0.205       [Li2SO4, CoPO4, CoSO4, Co(PO3)3]
# 2          -0.231  [Li2SO4, Co(PO3)3, LiCo(PO3)4, CoSO4]
# 3          -0.244   [Li2SO4, Li2S2O7, LiCo(PO3)4, CoSO4]
# 4          -0.518     [Li2SO4, Co(PO3)2, CoSO4, Li2S2O7]
# 5          -2.341         [Li2SO4, SO2, CoSO4, Co(PO3)2]
# 6          -2.366        [Li2SO4, Co(PO3)2, CoSO4, CoS2]
# 7          -2.403    [Li2SO4, CoS2, Co(PO3)2, Co3(PO4)2]
# 8          -2.435     [LiCoPO4, CoS2, Co3(PO4)2, Li2SO4]
# 9          -2.437         [Co3S4, LiCoPO4, CoS2, Li2SO4]
# 10         -2.507        [Co3S4, LiCoPO4, LiPO3, Li2SO4]
# 11         -2.520      [Co3S4, LiCoPO4, Li4P2O7, Li2SO4]
# 12         -2.561       [Li2SO4, Li3PO4, Li4P2O7, Co3S4]
# 13         -2.605          [Li2SO4, CoS2, Li3PO4, Co3S4]
# 14         -3.066            [Co3S4, Li3PO4, Li2S, CoS2]
# 15         -3.715          [Co3S4, Li3PO4, Li3PS4, Li2S]
# 16         -3.877          [Co9S8, Li3PO4, Li3PS4, Li2S]
# 17         -4.017             [Co9S8, Li2S, Li3PS4, CoP]
#
#                                                                                             Reaction
# 0        0.4621 O2 + LPS-L(0.5)CO -> 0.04018 Li2S2O7 + 0.08036 CoSO4 + 0.0625 CoPO4 + 0.08929 Li2SO4
# 1        0.452 O2 + LPS-L(0.5)CO -> 0.1205 CoSO4 + 0.002232 CoPO4 + 0.1295 Li2SO4 + 0.02009 Co(PO3)3
# 2   0.4509 O2 + LPS-L(0.5)CO -> 0.125 CoSO4 + 0.008929 Co(PO3)3 + 0.125 Li2SO4 + 0.008929 LiCo(PO3)4
# 3   0.4503 O2 + LPS-L(0.5)CO -> 0.001116 Li2S2O7 + 0.1272 CoSO4 + 0.1205 Li2SO4 + 0.01563 LiCo(PO3)4
# 4     0.4464 O2 + LPS-L(0.5)CO -> 0.008929 Li2S2O7 + 0.1116 CoSO4 + 0.03125 Co(PO3)2 + 0.1205 Li2SO4
# 5          0.442 O2 + LPS-L(0.5)CO -> 0.008929 SO2 + 0.1116 CoSO4 + 0.03125 Co(PO3)2 + 0.1295 Li2SO4
# 6        0.4152 O2 + LPS-L(0.5)CO -> 0.1027 CoSO4 + 0.03125 Co(PO3)2 + 0.1295 Li2SO4 + 0.008929 CoS2
# 7    0.2355 O2 + LPS-L(0.5)CO -> 0.06027 CoS2 + 0.00558 Co(PO3)2 + 0.1295 Li2SO4 + 0.02567 Co3(PO4)2
# 8    0.1964 O2 + LPS-L(0.5)CO -> 0.1071 Li2SO4 + 0.008929 Co3(PO4)2 + 0.07143 CoS2 + 0.04464 LiCoPO4
# 9        0.1786 O2 + LPS-L(0.5)CO -> 0.09821 Li2SO4 + 0.06696 CoS2 + 0.004464 Co3S4 + 0.0625 LiCoPO4
# 10      0.1618 O2 + LPS-L(0.5)CO -> 0.09821 Li2SO4 + 0.03348 LiPO3 + 0.03795 Co3S4 + 0.02902 LiCoPO4
# 11   0.1116 O2 + LPS-L(0.5)CO -> 0.07143 Li2SO4 + 0.02679 Li4P2O7 + 0.04464 Co3S4 + 0.008929 LiCoPO4
# 12    0.08929 O2 + LPS-L(0.5)CO -> 0.04762 Co3S4 + 0.01488 Li3PO4 + 0.05952 Li2SO4 + 0.02381 Li4P2O7
# 13        0.05357 O2 + LPS-L(0.5)CO -> 0.03571 CoS2 + 0.0625 Li3PO4 + 0.03571 Li2SO4 + 0.03571 Co3S4
# 14          LPS-L(0.5)CO -> 0.01786 O2 + 0.03571 Li2S + 0.03571 CoS2 + 0.0625 Li3PO4 + 0.03571 Co3S4
# 15      LPS-L(0.5)CO -> 0.02976 O2 + 0.03571 Li2S + 0.05655 Li3PO4 + 0.04762 Co3S4 + 0.005952 Li3PS4
# 16       LPS-L(0.5)CO -> 0.06151 O2 + 0.03571 Li2S + 0.04067 Li3PO4 + 0.01587 Co9S8 + 0.02183 Li3PS4
# 17            LPS-L(0.5)CO -> 0.1429 O2 + 0.1077 Li2S + 0.01449 Li3PS4 + 0.01054 Co9S8 + 0.04801 CoP

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LPS_LCO[0], LPS_LCO[2], 'o-', label= r'LPS-LiCoO$_2$')
p2 = plt.plot(LPS_L_CO[0], LPS_L_CO[2], 'o-', label= r'LPS-Li$_{0.5}$CoO$_2$')
legend = ax.legend(loc='lower center')

ax.invert_xaxis()
plt.show()

# %%
LPS_LCO_500 = get_chempots_phases_enthalpies(['Li','P','S','Co','O'],'Li3PS4','O', temp=500, binary='LiCoO2')
LPS_L_CO_500 = get_chempots_phases_enthalpies(['Li','P','S','Co','O'],'Li3PS4','O', temp=500, binary='Li0.5CoO2')
LPS_LCO_800 = get_chempots_phases_enthalpies(['Li','P','S','Co','O'],'Li3PS4','O', temp=800, binary='LiCoO2')
LPS_L_CO_800 = get_chempots_phases_enthalpies(['Li','P','S','Co','O'],'Li3PS4','O', temp=800, binary='Li0.5CoO2')
# Out:
# {'SO3': -0.14972980937470637, 'SO2': -0.19946079980922138, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': -0.14972980937470637, 'SO2': -0.19946079980922138, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': -0.2389397321974141, 'SO2': -0.3185049777184428, 'CO2': 0, 'O2': -0.4050231119405361}
# {'SO3': -0.2389397321974141, 'SO2': -0.3185049777184428, 'CO2': 0, 'O2': -0.4050231119405361}

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LPS_LCO[0], LPS_LCO[2], 'o-', c=colo1, label= r'LPS-LiCoO$_2$, 298 K')
p2 = plt.plot(LPS_LCO_500[5], LPS_LCO_500[2], 'o-', c=colo2, label= r'LPS-LiCoO$_2$, 500 K')
p3 = plt.plot(LPS_LCO_800[5], LPS_LCO_800[2], 'o-', c=colo3, label= r'LPS-LiCoO$_2$, 800 K')

# p4 = plt.plot(LPS_L_CO[0], LPS_L_CO[2], 'o--', c='#107ab0', label= r'LPS-Li$_{0.5}$CoO$_2$, 298 K')
# p5 = plt.plot(LPS_L_CO_500[5], LPS_L_CO_500[2], 'o--', c='#ff9408', label= r'LPS-Li$_{0.5}$CoO$_2$, 500 K')
# p6 = plt.plot(LPS_L_CO_800[5], LPS_L_CO_800[2], 'o--', c='#4da409', label= r'LPS-Li$_{0.5}$CoO$_2$, 800 K')

legend = ax.legend(loc='lower right')

ax.invert_xaxis()
plt.show()

# %% [markdown]
# ## LLZO

# %%
LLZO_LCO = get_chempots_phases_enthalpies(['Li','La','Zr','Co','O'],'Li7La3Zr2O12','O', binary='LiCoO2')
LLZO_L_CO = get_chempots_phases_enthalpies(['Li','La','Zr','Co','O'],'Li7La3Zr2O12','O', binary='Li0.5CoO2')

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LLZO_LCO[0], LLZO_LCO[2], 'o-', label= r'llzo-lco')
p2 = plt.plot(LLZO_L_CO[5], LLZO_L_CO[2], 'o-', label= r'llzo-l$_{0.5}$co')

legend = ax.legend(loc='lower center')

ax.invert_xaxis()
plt.show()

# %%
LLZO_LCO_500 = get_chempots_phases_enthalpies(['Li','La','Zr','Co','O'],'Li7La3Zr2O12','O', temp=500, binary='LiCoO2')
LLZO_L_CO_500 = get_chempots_phases_enthalpies(['Li','La','Zr','Co','O'],'Li7La3Zr2O12','O', temp=500, binary='Li0.5CoO2')
LLZO_LCO_800 = get_chempots_phases_enthalpies(['Li','La','Zr','Co','O'],'Li7La3Zr2O12','O', temp=800, binary='LiCoO2')
LLZO_L_CO_800 = get_chempots_phases_enthalpies(['Li','La','Zr','Co','O'],'Li7La3Zr2O12','O', temp=800, binary='Li0.5CoO2')
# Out:
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}

# %%
fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LLZO_LCO[0], LLZO_LCO[2], 'o-', c='#107ab0', label= r'llzo-lco, 298 K')
p2 = plt.plot(LLZO_LCO_500[5], LLZO_LCO_500[2], 'o-', c='#ff9408', label= r'llzo-lco, 500 K')
p3 = plt.plot(LLZO_LCO_800[5], LLZO_LCO_800[2], 'o-', c='#4da409', label= r'llzo-lco, 800 K')

# p4 = plt.plot(LLZO_L_CO[0], LLZO_L_CO[2], 'o--', c='#107ab0', label= r'llzo-l$_{0.5}$co, 300 K')
# p5 = plt.plot(LLZO_L_CO_500[5], LLZO_L_CO_500[2], 'o--', c='#ff9408', label= r'llzo-l$_{0.5}$co, 500 K')
# p6 = plt.plot(LLZO_L_CO_800[5], LLZO_L_CO_800[2], 'o--', c='#4da409', label= r'llzo-l$_{0.5}$co, 800 K')

legend = ax.legend(loc='lower left')

ax.invert_xaxis()
plt.show()

# %%
LATP = get_chempots_phases_enthalpies(['Li','Al','Ti','P','O'],'Li13Al3Ti17P30O120','O')
LLZO = get_chempots_phases_enthalpies(['Li','La','Zr','O'],'Li7La3Zr2O12','O')
# Out:
# 183.0
# 24.0

# %%
LATP_500 = get_chempots_phases_enthalpies(['Li','Al','Ti','P','O'],'Li13Al3Ti17P30O120','O', temp=500)
LLZO_500 = get_chempots_phases_enthalpies(['Li','La','Zr','O'],'Li7La3Zr2O12','O', temp=500)
LATP_800 = get_chempots_phases_enthalpies(['Li','Al','Ti','P','O'],'Li13Al3Ti17P30O120','O', temp=800)
LLZO_800 = get_chempots_phases_enthalpies(['Li','La','Zr','O'],'Li7La3Zr2O12','O', temp=800)
# Out:
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# 183.0
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.2699917116035555}
# 24.0
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}
# 183.0
# {'SO3': 0, 'SO2': 0, 'CO2': 0, 'O2': -0.4050231119405361}
# 24.0

# %%
pnds.options.display.float_format = '{:.3f}'.format
table = pnds.DataFrame({r'$\mu_O$ (eV)':LLZO_LCO[5],
                      'Phase Equilibria':LLZO_LCO[1],
                    r'$\Delta H_{rxn}$ at $\mu_O$':LLZO_LCO[2],
                        'Reaction':LLZO_LCO[4]})
pnds.set_option('max_colwidth', 400)
display(table)
# Out:
#     $\Delta H_{rxn}$ at $\mu_O$  $\mu_O$ (eV)  \
# 0                        -0.064         0.000
# 1                        -0.045        -0.126
# 2                        -0.004        -0.953
# 3                         0.000        -1.151
# 4                         0.000        -2.560
# 5                        -0.000        -2.644
# 6                        -0.002        -2.660
# 7                        -0.082        -2.903
# 8                        -1.094        -5.602
# 9                        -1.164        -5.742
# 10                       -1.420        -6.213
# 11                       -1.584        -6.415
# 12                       -1.597        -6.429
#
#                           Phase Equilibria  \
# 0      [Li2O2, La2O3, La2Zr2O7, Li7Co5O12]
# 1   [Li6Zr2O7, La2O3, La2Zr2O7, Li7Co5O12]
# 2     [Li6Zr2O7, La2O3, LiCoO2, Li7Co5O12]
# 3       [Li5CoO4, La2O3, LiCoO2, Li6Zr2O7]
# 4       [Li6Zr2O7, La2O3, LiCoO2, Li6CoO4]
# 5          [Li6Zr2O7, CoO, Li6CoO4, La2O3]
# 6           [Co, Li6Zr2O7, Li6CoO4, La2O3]
# 7              [Li6Zr2O7, La2O3, Co, Li2O]
# 8         [Li6Zr2O7, La2O3, Zr6Co23, Li2O]
# 9            [Li2O, La2O3, Zr6Co23, ZrCo2]
# 10             [Li, La2O3, Zr6Co23, ZrCo2]
# 11              [Li, La2O3, La2Co3, ZrCo2]
# 12              [Li, La3Co, La2Co3, ZrCo2]
#
#                                                                                                                               Reaction
# 0       0.03646 O2 + Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.01042 La2O3 + 0.04792 Li2O2 + 0.025 Li7Co5O12 + 0.02083 La2Zr2O7
# 1    0.0125 O2 + Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.02639 La2O3 + 0.01597 Li6Zr2O7 + 0.025 Li7Co5O12 + 0.004861 La2Zr2O7
# 2   0.005208 O2 + Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.03125 La2O3 + 0.02083 Li6Zr2O7 + 0.01042 Li7Co5O12 + 0.07292 LiCoO2
# 3                   Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.03125 La2O3 + 0.02083 Li6Zr2O7 + 0.1198 LiCoO2 + 0.005208 Li5CoO4
# 4     Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.001042 O2 + 0.03125 La2O3 + 0.02083 Li6Zr2O7 + 0.004167 Li6CoO4 + 0.1208 LiCoO2
# 5          Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.03125 O2 + 0.1007 CoO + 0.02083 Li6Zr2O7 + 0.02431 Li6CoO4 + 0.03125 La2O3
# 6            Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.0816 O2 + 0.02083 Li6Zr2O7 + 0.1007 Co + 0.02431 Li6CoO4 + 0.03125 La2O3
# 7               Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.09375 O2 + 0.125 Co + 0.03125 La2O3 + 0.02083 Li6Zr2O7 + 0.07292 Li2O
# 8        Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.1264 O2 + 0.1218 Li2O + 0.03125 La2O3 + 0.005435 Zr6Co23 + 0.004529 Li6Zr2O7
# 9            Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.1354 O2 + 0.01894 ZrCo2 + 0.03125 La2O3 + 0.003788 Zr6Co23 + 0.1354 Li2O
# 10             Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.2031 O2 + 0.01894 ZrCo2 + 0.03125 La2O3 + 0.003788 Zr6Co23 + 0.2708 Li
# 11                Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.224 O2 + 0.01736 La2O3 + 0.04167 ZrCo2 + 0.2708 Li + 0.01389 La2Co3
# 12                Li0.27083333La0.0625Zr0.04166667Co0.125O0.5 -> 0.25 O2 + 0.008929 La2Co3 + 0.04167 ZrCo2 + 0.2708 Li + 0.01488 La3Co

# %%
table.to_csv('out.txt', sep='\t')

# %%
table = pnds.DataFrame({r'$\mu_O$ (eV)':LLZO[5],
                      'Phase Equilibria':LLZO[1],
                    r'$\Delta H_{rxn}$ at $\mu_O$':LLZO[2],
                        'Reaction':LLZO[4]})
pnds.set_option('max_colwidth', 400)

display(table)
# Out:
#    $\Delta H_{rxn}$ at $\mu_O$  $\mu_O$ (eV)          Phase Equilibria  \
# 0                       -0.024         0.000  [La2Zr2O7, La2O3, Li2O2]
# 1                       -0.005        -0.126  [Li2O2, Li6Zr2O7, La2O3]
# 2                        0.000        -0.387   [La2O3, Li6Zr2O7, Li2O]
# 3                        0.000        -6.117       [La2O3, Zr3O, Li2O]
# 4                       -0.012        -6.204         [Zr, Li2O, La2O3]
# 5                       -0.014        -6.213           [Zr, La2O3, Li]
# 6                       -0.101        -6.491              [Zr, Li, La]
#
#                                                         Reaction
# 0     1.75 O2 + Li7La3Zr2O12 -> La2Zr2O7 + 3.5 Li2O2 + 0.5 La2O3
# 1     0.25 O2 + Li7La3Zr2O12 -> Li6Zr2O7 + 0.5 Li2O2 + 1.5 La2O3
# 2                Li7La3Zr2O12 -> 0.5 Li2O + 1.5 La2O3 + Li6Zr2O7
# 3  Li7La3Zr2O12 -> 1.667 O2 + 0.6667 Zr3O + 1.5 La2O3 + 3.5 Li2O
# 4             Li7La3Zr2O12 -> 2 O2 + 2 Zr + 1.5 La2O3 + 3.5 Li2O
# 5              Li7La3Zr2O12 -> 3.75 O2 + 2 Zr + 1.5 La2O3 + 7 Li
# 6                      Li7La3Zr2O12 -> 6 O2 + 2 Zr + 3 La + 7 Li

# %%
plt.figure(1)
fig, ax = plt.subplots()
ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')

p1 = plt.plot(LATP[0], LATP[2], 'o-', label= r'latp')
p2 = plt.plot(LLZO[0], LLZO[2], 'o-', label= r'llzo')
p3 = plt.plot(LPS[0], LPS[2], 'o-', label= r'lps')
ax.legend(loc='lower center')
ax.invert_xaxis()

plt.figure(2)

fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')
p3 = plt.plot(LATP[0], LATP[2], 'o-', label= r'latp, 298 K')
p4 = plt.plot(LATP_500[5], LATP_500[2], 'o-', label= r'latp, 500 K')
p5 = plt.plot(LATP_800[5], LATP_800[2], 'o-', label= r'latp, 800 K')
ax.invert_xaxis()
ax.legend(loc='lower left')

plt.figure(3)

fig, ax = plt.subplots()

ax.set_ylabel(r'$\Delta$H of Reaction (eV/atom)')
ax.set_xlabel(r'$\mu_O$ (eV)')
p3 = plt.plot(LLZO[0], LLZO[2], 'o-', label= r'llzo, 298 K')
p4 = plt.plot(LLZO_500[5], LLZO_500[2], 'o-', label= r'llzo, 500 K')
p5 = plt.plot(LLZO_800[5], LLZO_800[2], 'o-', label= r'llzo, 800 K')
ax.invert_xaxis()
ax.legend(loc='lower left')

# %%
li = get_chempots_phases_enthalpies(['Li','O'],'Li','O')

# %%
table = pnds.DataFrame({r'$\mu_O$ (eV)':LPS[5],
                      'Phase Equilibria':LPS[1],
                     r'$\Delta H_{rxn}$ at $\mu_O$':LPS[2],
                        'Reaction':LPS[4]})
pnds.set_option('max_colwidth', 400)

display(table)
# Out:
#    $\Delta H_{rxn}$ at $\mu_O$  $\mu_O$ (eV)         Phase Equilibria  \
# 0                       -5.295         0.000     [Li2S2O7, P2O5, SO3]
# 1                       -1.753        -1.771     [SO2, P2O5, Li2S2O7]
# 2                       -1.300        -2.012    [SO2, LiPO3, Li2S2O7]
# 3                       -0.726        -2.341     [SO2, LiPO3, Li2SO4]
# 4                       -0.313        -2.594    [P2S7, LiPO3, Li2SO4]
# 5                       -0.214        -2.722  [Li2SO4, Li4P2O7, P2S7]
# 6                       -0.151        -2.807   [P2S7, Li3PO4, Li2SO4]
# 7                        0.000        -3.023                 [Li3PS4]
#
#                                                            Reaction
# 0                     8 O2 + Li3PS4 -> SO3 + 1.5 Li2S2O7 + 0.5 P2O5
# 1                   7.5 O2 + Li3PS4 -> SO2 + 1.5 Li2S2O7 + 0.5 P2O5
# 2                          7 O2 + Li3PS4 -> 2 SO2 + LiPO3 + Li2S2O7
# 3                         6.5 O2 + Li3PS4 -> 3 SO2 + LiPO3 + Li2SO4
# 4       3.125 O2 + Li3PS4 -> 0.25 LiPO3 + 1.375 Li2SO4 + 0.375 P2S7
# 5  2.944 O2 + Li3PS4 -> 0.1111 Li4P2O7 + 1.278 Li2SO4 + 0.3889 P2S7
# 6             2.8 O2 + Li3PS4 -> 0.2 Li3PO4 + 1.2 Li2SO4 + 0.4 P2S7
# 7                                                  Li3PS4 -> Li3PS4
